# %%
#Problems 22 & 23

# %%
x = var('x')

# %%
def f(x): return 1/x

# %%
def V(x): return pi*(1/x)^2

# %%
def S(x): return (2*pi/x)*sqrt(1 + 1/x^4)

# %%
p = []

# %%
p.append(plot(f(x),(x,0.1,1), color='blue', legend_label='f(x)'))

# %%
p.append(plot(f(x),(x,1,10), color='blue', fill=true))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
q = []

# %%
q.append(plot(V(x),(x,0.5,1), color='blue', legend_label='V(x)'))

# %%
q.append(plot(V(x),(x,1,10), color='blue', fill=true))

# %%
sum(q)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
r = []

# %%
r.append(plot(S(x),(x,0.5,1), color='blue', legend_label='S(x)'))

# %%
r.append(plot(S(x),(x,1,10), color='blue', fill=true))

# %%
sum(r)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
int1 = integral(f(x), x, 1, oo)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /ext/sage/9.5/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/interfaces/maxima_lib.py in sr_integral(self, *args)
#     792         try:
# --> 793             return max_to_sr(maxima_eval(([max_integrate],[sr_to_max(SR(a)) for a in args])))
#     794         except RuntimeError as error:
#
# /ext/sage/9.5/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/libs/ecl.pyx in sage.libs.ecl.EclObject.__call__ (build/cythonized/sage/libs/ecl.c:8437)()
#     837         lispargs = EclObject(list(args))
# --> 838         return ecl_wrap(ecl_safe_apply(self.obj,(<EclObject>lispargs).obj))
#     839
#
# /ext/sage/9.5/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/libs/ecl.pyx in sage.libs.ecl.ecl_safe_apply (build/cythonized/sage/libs/ecl.c:5979)()
#     358         else:
# ...

# %%
int2 = integral(V(x), x, 1, oo)

# %%
int2
# Out:
# pi

# %%
int3 = integral(S(x), x, 1, oo)
# Out:
# // Giac share root-directory:/ext/sage/9.5/local/share/giac/
# // Giac share root-directory:/ext/sage/9.5/local/share/giac/
# Help file /ext/sage/9.5/local/share/giac/doc/fr/aide_cas not found
# Added 0 synonyms
# No checks were made for singular points of antiderivative -pi*2/2*(sqrt((1/sageVARx)^4+1)+1/2*ln(sqrt((1/sageVARx)^4+1)-1)-1/2*ln(sqrt((1/sageVARx)^4+1)+1)) for definite integration in [1,+infinity]

# %%
int3
# Out:
# +Infinity
